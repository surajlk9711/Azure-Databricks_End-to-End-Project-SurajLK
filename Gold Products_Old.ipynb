# %% [markdown]
# # **DLT Pipeline**

# %% [markdown]
# **Streaming Tables**

# %%
from pyspark import pipelines as dp
from pyspark.sql.functions import *
from pyspark.sql.types import *
import dlt
# Out:
#     <html>
#       <div style="font-size:18px">
#         The Delta Live Tables (DLT) module is not supported on this cluster.
#         You should either <a href="?o=7405604563459955#joblist/pipelines/create?initialSource=%2FUsers%2Fsurajlk9755%40gmail.com%2FDatabricks-ETE+Project%2FGold+Products_Old&redirectNotebookId=2803923049452219">create a new pipeline</a> or use an existing pipeline to run DLT code.
#       </div>
#     </html>
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /databricks/python/lib/python3.12/site-packages/pyspark/pipelines/__init__.py:28
#      27 try:
# ---> 28     from dlt import *
#      29 except ImportError:
#
# ModuleNotFoundError: No module named 'dlt'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File <command-2803923049452222>, line 1
# ----> 1 from pyspark import pipelines as dp
#       2 from pyspark.sql.functions import *
#       3 from pyspark.sql.types import *
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/pipelines/__init__.py:30
#      28         from dlt import *
#      29     except ImportError:
# ---> 30         raise PySparkException(errorClass="PIPELINES_NOT_SUPPORTED")
#      31 # END: EDGE
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/errors/exceptions/base.py:51, in PySparkException.__init__(self, message, errorClass, messageParameters, contexts)
#      48 self._error_reader = ErrorClassesReader()
#      50 if message is None:
# ---> 51     self._message = self._error_reader.get_error_message(
#      52         cast(str, errorClass), cast(Dict[str, str], messageParameters)
#      53     )
#      54 else:
#      55     self._message = message
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/errors/utils.py:122, in ErrorClassesReader.get_error_message(self, errorClass, messageParameters)
#     120 message_parameters_from_template = re.findall("<([a-zA-Z0-9_-]+)>", message_template)
#     121 # BEGIN-EDGE: changed == to <= to allow extra params from unknown subclass fallback
# --> 122 assert set(message_parameters_from_template) <= set(messageParameters), (
#     123     f"Undefined error message parameter for error class: {errorClass}. "
#     124     f"Parameters: {messageParameters}"
#     125 )
#     126 # END-EDGE
#     128 def replace_match(match: Match[str]) -> str:
#
# TypeError: 'NoneType' object is not iterable

# %%
# Expectations
my_rules = {
  "rule1" : "product_id IS NOT NULL",
  "rule2" : "product_name IS NOT NULL"
}

# %%
@dlt.table()
@dlt.expect_all_or_drop(my_rules)
def DimProducts_stage():
  df = spark.readStream.table("databricks_cata.silver.products_silver")
  return df

# %% [markdown]
# **Streaming Table**

# %%
#@dlt.expect_all_or_drop(my_rules)
#def DimProducts_stage():
 # df = spark.readStream.table("databricks_cata.silver.products_silver")
  #return df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-8507982967462353>, line 1
# ----> 1 @dlt.table()
#       2
#       3 def DimProducts_stage():
#       4   df = spark.readStream.table("databricks_cata.silver.products_silver")
#       5   return df
#
# NameError: name 'dlt' is not defined

# %% [markdown]
# **Streaming View**

# %%
@dlt.view()

def DimProducts_view():
  df = spark.readStream.table("DimProducts_stage")
  return df

# %% [markdown]
# **DimProducts**

# %%
dlt.create_streaming_table("DimProducts")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-8507982967462371>, line 1
# ----> 1 dlt.create_streaming_table("DimProducts")
#
# NameError: name 'dlt' is not defined

# %%
dlt.apply_changes(
    target="DimProducts",
    source="DimProducts_view",
    keys=["product_id"],
    sequence_by=col("product_id"),   # ✅ must be timestamp or version column
    stored_as_scd_type=2
)
