# %% [markdown]
# # **DLT Pipeline**

# %% [markdown]
# **Streaming Tables**

# %%
from pyspark import pipelines as dp
from pyspark.sql.functions import *
# Out:
#     <html>
#       <div style="font-size:18px">
#         The Delta Live Tables (DLT) module is not supported on this cluster.
#         You should either <a href="?o=7405604563459955#joblist/pipelines/create?initialSource=%2FUsers%2Fsurajlk9755%40gmail.com%2FDatabricks-ETE+Project%2FGold+Products&redirectNotebookId=2242283733563791">create a new pipeline</a> or use an existing pipeline to run DLT code.
#       </div>
#     </html>
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File <command-8507982967462352>, line 1
# ----> 1 import dlt
#       2 from pyspark.sql.functions import *
#
# ModuleNotFoundError: No module named 'dlt'

# %%
# Expectations
my_rules = {
  "rule1" : "product_id IS NOT NULL",
  "rule2" : "product_name IS NOT NULL"
}

# %%
# This cell was removed because DimProducts is defined via Auto CDC flow in Cell 11-12
# Original code:
# @dp.table()
# @dp.expect_all_or_drop(my_rules)
# def DimProducts():
#   df = spark.readStream.table("databricks_cata.silver.products_silver")
#   return df

# %% [markdown]
# **Streaming Table**

# %%
@dp.table()
@dp.expect_all_or_drop(my_rules)
def DimProducts_stage():
  df = spark.readStream.table("databricks_cata.silver.products_silver")
  return df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-8507982967462353>, line 1
# ----> 1 @dlt.table()
#       2
#       3 def DimProducts_stage():
#       4   df = spark.readStream.table("databricks_cata.silver.products_silver")
#       5   return df
#
# NameError: name 'dlt' is not defined

# %% [markdown]
# **Streaming View**

# %%
@dlt.view()

def DimProducts_view():
  df = spark.readStream.table("DimProducts_stage")
  return df

# %% [markdown]
# **DimProducts**

# %%
dp.create_streaming_table("DimProducts")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-8507982967462371>, line 1
# ----> 1 dlt.create_streaming_table("DimProducts")
#
# NameError: name 'dlt' is not defined

# %%
dp.create_auto_cdc_flow(
    target = "DimProducts",
    source = "DimProducts_view",
    keys = ["product_id"],
    sequence_by = "product_id",
    stored_as_scd_type = 2
)
